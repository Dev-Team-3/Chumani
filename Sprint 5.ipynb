# %%
import pandas as pd
data = pd.read_csv("Sprint 5.csv") 
data
# Out:
#        Chips  Quantity Price Cooldrinks  Quantity.1 Price.1            Pies  \
# 0      Simba        30   R20       Coke          50     R10    Pepper Steak
# 1       Lays        45   R21      Fanta          50     R10         Chicken
# 2     Fritoz        25   R14     Sprite          50     R10  Steak & kidney
# 3  Niks naks        45   R15      Pepsi          50     R10           Vegan
# 4   Pretzels        40   R18     Stoney          50     R10         sausage
# 5    Squirls        25   R12   Aqueelah          50     R12      burger pie
#
#    Quantity.2 Price.2   Fruit  Quantity.3 Price.3     Cupcakes  Quantity.4  \
# 0          40     R20    Pear          35      R2      Vanilla          65
# 1          50     R22   Apple          45      R2    Chocolate          40
# 2          45     R25  Orange          40      R3  Red velevet          55
# 3          30     R23   peach          35      R5      Caramel          35
# ...

# %%
import pandas as pd
data = pd.read_csv("Sprint 5.csv") 
data[['Chips','Quantity','Price']]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
y =[20, 21, 14, 15, 18, 12,]
plt.hist(y)
plt.title('Prices')
plt.xlabel('Prices R')
plt.ylabel('Frequency')    
plt.show()

# %%
x = ['Apple','Orange','Pawpaw','Grape','Pear','Peach']
y = [2, 3, 18, 20, 2, 5]
plt.plot(x, y, 'go-')
plt.xlabel('Fruit')
plt.ylabel('Price')


plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
y = [30, 45, 25, 45, 40, 25]
x = ['Simba','Lays','Fritoz','Nik naks','Pretzels','Squirls']
plt.plot(x, y,  'g*--')
plt.title("Chips vs Quantity")
plt.ylabel("Quantity")
plt.xlabel("Chips")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
y = [10,10,10,10,10,12]
x = ['Coke','Fanta','Sprite','Pepsi','Stoney','Aqueelah']
plt.plot(x, y,  'g*--')
plt.xlabel('Cooldrinks')
plt.ylabel('Prices')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
y = [20, 22, 25, 23, 24, 25]
x = ['Pepper Steak','Chicken Pie','Steak & Kidney','Vegan','Sausage','Burger Pie'    ]

# %%
import numpy as np
import matplotlib.pyplot as plt

Price=[15, 25, 30, 45, 20, 25, 7, 10, 15, 8, 9, 6, 2, 2, 3, 5, 20, 18, 20, 21, 14, 15, 18, 12]

Quantity=[50, 50, 50, 50, 50, 50, 65, 30, 45, 35, 60, 55, 65, 45, 70, 55, 35, 25, 40, 35, 40]

color =np.random.rand(42)

size = np.random.randint(20, 30, 10)

plt.scatter(Price, Quantity, c=color, s=size)

plt.xlabel('Values from list Price')

plt.ylabel('Values from list Quantity')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-977ec3fbf2f3> in <module>
#      10 size = np.random.randint(20, 30, 10)
#      11
# ---> 12 plt.scatter(Price, Quantity, c=color, s=size)
#      13
#      14 plt.xlabel('Values from list Price')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...
